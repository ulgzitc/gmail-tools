# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/home/ender/Projects/gmail-tools/misc'

# %%
os.chdir("../../env/logs/")

# %%
df = pd.read_json("messages.json")

# %%
df.iloc[0]['messages']
# Out:
# '[image: Google] You allowed EmailFilter access to some of your Google Account data javokhir.coding@gmail.com If you didn’t allow EmailFilter access to some of your Google Account data, someone else may be trying to access your Google Account data. Take a moment now to check your account activity and secure your account. Check activity <> To make changes at any time to the access that EmailFilter has to your data, go to your Google Account <> You can also see security activity at You received this email to let you know about important changes to your Google Account and services. © 2026 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA'

# %%
df.iloc[0]['label']
# Out:
# 'BEEF'

# %%
df.iloc[0]['labels']
# Out:
# ['UNREAD', 'CATEGORY_UPDATES', 'INBOX']

# %%
df.loc[0]
# Out:
# messages    [image: Google] You allowed EmailFilter access...
# labels                      [UNREAD, CATEGORY_UPDATES, INBOX]
# label                                                    BEEF
# Name: 0, dtype: object

# %%
df['labels']
# Out:
# 0       [UNREAD, CATEGORY_UPDATES, INBOX]
# 1       [UNREAD, CATEGORY_UPDATES, INBOX]
# 2       [UNREAD, CATEGORY_UPDATES, INBOX]
# 3       [UNREAD, CATEGORY_UPDATES, INBOX]
# 4       [UNREAD, CATEGORY_UPDATES, INBOX]
#                       ...
# 6000                  [CATEGORY_PERSONAL]
# 6001         [CATEGORY_PROMOTIONS, INBOX]
# 6002                  [CATEGORY_PERSONAL]
# 6003                  [CATEGORY_PERSONAL]
# 6004            [CATEGORY_UPDATES, INBOX]
# Name: labels, Length: 6005, dtype: object

# %%
df['label']
# Out:
# 0       BEEF
# 1       BEEF
# 2       BEEF
# 3       BEEF
# 4       BEEF
#         ...
# 6000    BEEF
# 6001    BEEF
# 6002    BEEF
# 6003    BEEF
# 6004    BEEF
# Name: label, Length: 6005, dtype: str

# %%
df
# Out:
#                                                messages  \
# 0     [image: Google] You allowed EmailFilter access...
# 1     [image: Google] You allowed EmailFilter access...
# 2     [image: Google] You allowed EmailFilter access...
# 3     New Topic in General : Contextual Contaminatio...
# 4     New Topic in General : I'm new around here Kag...
# ...                                                 ...
# 6000  Please take a second to make sure we&#39;ve go...
# 6001  To view this content open the following URL in...
# 6002  To view this content open the following URL in...
# 6003  Please take a second to make sure we&#39;ve go...
# 6004  Qani, ketdik Javokhir Googlega xush kelibsiz. ...
#
#                                  labels label
# 0     [UNREAD, CATEGORY_UPDATES, INBOX]  BEEF
# 1     [UNREAD, CATEGORY_UPDATES, INBOX]  BEEF
# 2     [UNREAD, CATEGORY_UPDATES, INBOX]  BEEF
# 3     [UNREAD, CATEGORY_UPDATES, INBOX]  BEEF
# 4     [UNREAD, CATEGORY_UPDATES, INBOX]  BEEF
# ...

# %%
df['label'].unique()
# Out:
# <ArrowStringArray>
# ['BEEF']
# Length: 1, dtype: str
